# %%
# %pip install anthropic python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: anthropic in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (0.94.1)
# Requirement already satisfied: python-dotenv in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (1.2.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.14.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from anthropic) (4.12.1)
# Requirement already satisfied: sniffio in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.17.0)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from anthropic) (2.13.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->anthropic) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: pydantic-core==2.46.0 in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/saw1518/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"


def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# Start with an empty message list
messages = []

# Add the initial user question
add_user_message(messages, "Define quantum computing in one sentence")

# Get Claude's response
answer = chat(messages)



# Add Claude's response to the conversation history
add_assistant_message(messages, answer)

# Add a follow-up question
add_user_message(messages, "Write another sentence")

# Get the follow-up response with full context
final_answer = chat(messages)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       2 messages = []
#       4 # Add the initial user question
# ----> 5 add_user_message(messages, "Define quantum computing in one sentence")
#       7 # Get Claude's response
#       8 answer = chat(messages)
#
# NameError: name 'add_user_message' is not defined

# %%
messages = []



while True:
    user_input = input("You: ")
    add_user_message(messages, user_input)
    response = chat(messages)
    print(f"Claude: {response}")
    add_assistant_message(messages, response)
# Out:
# Claude: 2 + 2 = 4
# Claude: If you mean 4 + 45 (adding 45 to our previous result), then:
#
# 4 + 45 = 49
# Claude: Goodbye! Have a great day! 👋
